# %% [markdown]
# # Pymaceuticals Inc.
# ---
#
# ## Analysis

# %% [markdown]
# ### Treatments Timepoints
#         Looking at the bar chart for the timepoints for every treatment, we notice that treatments vary in length. This inconsistency could be an aspect of the study to further look into, as having uniform timepoints would make comparisons more consistent and reputable.

# %% [markdown]
# ![](bar_drug_timepts.png)

# %% [markdown]
# ### Population by Gender
#             The pie chart illustrated below represents that genders for the mice used in the study. The population seems to be almost evenly distributed across genders. This would eliminate any irregularities that can arise from the gender variable.

# %% [markdown]
# ![](Gender_piechart.png)

# %% [markdown]
# ### Final Tumor Volumes for Capomulin, Ramicane, Infubinol, and Ceftamin
#     The Box and Whisker plot below illustrates all of the final tumor volumes for each mice in 4 of the treatments in the study. The results illustrates that, with the exception of Infubinol, none of the treatments had outliers in final tumor volumes. The only outlier final tumor volume, was 36.321346, found in the Infubinol treatment results. This can infer that results in final tumor volume for mice in Capomulin, Ramicane, Infubinol, and Ceftamin, were evenly distributed.

# %% [markdown]
# ![](Box_whisker_outliers.png)

# %% [markdown]
# ### Capomulin progression for one mouse
#     The line graph below depicts the progression of the tumor volume throughout the treatment period. The graph demonstrates a negative correlation between timepoints and tumor volume, which reflects on the effectiveness of the drug. As time progresses, the tumor volume for this particular mouse decreases gradually. In this particular case, Capomulin seems to have a desired outcome, which is to decrease (or eliminate) tumor volume.

# %% [markdown]
# ![](line_graph.png)

# %% [markdown]
# ### Capomulin's Correlation Analysis for Average Weight and Tumor Volume
#     The graph underneath depicts the relationship between the average weight and tumor volume across mice treated with Capomulin. The graph shows a positive relationship between average weight and tumor volume, which mean

# %% [markdown]
# ![](scatter_plot.png)

# %% [markdown]
# ### Regression Analysis for Average Weight and Tumor Volume

# %% [markdown]
# ![](regression.png)

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import os

# Study data files
mouse_metadata_path = os.path.join('data', 'Mouse_metadata.csv')
study_results_path = os.path.join('data', 'Study_results.csv')

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single DataFrame
complete_df = pd.merge(study_results, mouse_metadata, on='Mouse ID', how='left')

# Display the data table for preview
complete_df
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0        b128          0           45.000000                 0    Capomulin
# 1        f932          0           45.000000                 0     Ketapril
# 2        g107          0           45.000000                 0     Ketapril
# 3        a457          0           45.000000                 0     Ketapril
# 4        c819          0           45.000000                 0     Ketapril
# ...       ...        ...                 ...               ...          ...
# 1888     r944         45           41.581521                 2    Capomulin
# 1889     u364         45           31.023923                 3    Capomulin
# 1890     p438         45           61.433892                 1     Ceftamin
# 1891     x773         45           58.634971                 4      Placebo
# 1892     b879         45           72.555239                 2     Stelasyn
#
#          Sex  Age_months  Weight (g)
# ...

# %%
# Checking the number of mice.
complete_df['Mouse ID'].nunique()
# Out:
# 249

# %%
#look at the data of dataframe to make sure everything is uniform
complete_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1893 entries, 0 to 1892
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Mouse ID            1893 non-null   object
#  1   Timepoint           1893 non-null   int64
#  2   Tumor Volume (mm3)  1893 non-null   float64
#  3   Metastatic Sites    1893 non-null   int64
#  4   Drug Regimen        1893 non-null   object
#  5   Sex                 1893 non-null   object
#  6   Age_months          1893 non-null   int64
#  7   Weight (g)          1893 non-null   int64
# dtypes: float64(1), int64(4), object(3)
# memory usage: 118.4+ KB

# %%
# Our data should be uniquely identified by Mouse ID and Timepoint
# Get the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
duplicates = complete_df.loc[complete_df.duplicated(['Mouse ID' , 'Timepoint']), 'Mouse ID'].unique()
duplicates
# Out:
# array(['g989'], dtype=object)

# %%
# Optional: Get all the data for the duplicate mouse ID. 
duplicate_mouse = complete_df.loc[complete_df['Mouse ID']=='g989']
duplicate_mouse
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 107      g989          0           45.000000                 0     Propriva
# 137      g989          0           45.000000                 0     Propriva
# 329      g989          5           48.786801                 0     Propriva
# 360      g989          5           47.570392                 0     Propriva
# 620      g989         10           51.745156                 0     Propriva
# 681      g989         10           49.880528                 0     Propriva
# 815      g989         15           51.325852                 1     Propriva
# 869      g989         15           53.442020                 0     Propriva
# 950      g989         20           55.326122                 1     Propriva
# 1111     g989         20           54.657650                 1     Propriva
# 1195     g989         25           56.045564                 1     Propriva
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
clean_df = complete_df[complete_df['Mouse ID'].isin(duplicates)==False]
clean_df
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0        b128          0           45.000000                 0    Capomulin
# 1        f932          0           45.000000                 0     Ketapril
# 2        g107          0           45.000000                 0     Ketapril
# 3        a457          0           45.000000                 0     Ketapril
# 4        c819          0           45.000000                 0     Ketapril
# ...       ...        ...                 ...               ...          ...
# 1888     r944         45           41.581521                 2    Capomulin
# 1889     u364         45           31.023923                 3    Capomulin
# 1890     p438         45           61.433892                 1     Ceftamin
# 1891     x773         45           58.634971                 4      Placebo
# 1892     b879         45           72.555239                 2     Stelasyn
#
#          Sex  Age_months  Weight (g)
# ...

# %%
# Checking the number of mice in the clean DataFrame.
clean_df['Mouse ID'].nunique()
# Out:
# 248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume. 
# Assemble the resulting series into a single summary DataFrame.
mean_tumor = clean_df.groupby('Drug Regimen')['Tumor Volume (mm3)'].mean()
median_tumor = clean_df.groupby('Drug Regimen')['Tumor Volume (mm3)'].median()
var_tumor = clean_df.groupby('Drug Regimen')['Tumor Volume (mm3)'].var()
std_tumor = clean_df.groupby('Drug Regimen')['Tumor Volume (mm3)'].std()
sem_tumor = clean_df.groupby('Drug Regimen')['Tumor Volume (mm3)'].sem()

tumor_df = pd.DataFrame({
    'Mean Tumor Volume': mean_tumor, 
    'Median Tumor Volume': median_tumor,
    'Tumor Volume Variance': var_tumor, 
    'Tumor Volume Standard Deviation': std_tumor, 
    'Tumor Volume SEM': sem_tumor
})
tumor_df
# Out:
#               Mean Tumor Volume  Median Tumor Volume  Tumor Volume Variance  \
# Drug Regimen
# Capomulin             40.675741            41.557809              24.947764
# Ceftamin              52.591172            51.776157              39.290177
# Infubinol             52.884795            51.820584              43.128684
# Ketapril              55.235638            53.698743              68.553577
# Naftisol              54.331565            52.509285              66.173479
# Placebo               54.033581            52.288934              61.168083
# Propriva              52.320930            50.446266              43.852013
# Ramicane              40.216745            40.673236              23.486704
# Stelasyn              54.233149            52.431737              59.450562
# Zoniferol             53.236507            51.818479              48.533355
#
#               Tumor Volume Standard Deviation  Tumor Volume SEM
# Drug Regimen
# ...

# %%
# A more advanced method to generate a summary statistics table of mean, median, variance, standard deviation,
# and SEM of the tumor volume for each regimen (only one method is required in the solution)

# Using the aggregation method, produce the same summary statistics in a single line
summary_table = clean_df.groupby('Drug Regimen').agg({'Tumor Volume (mm3)': ['mean', 'median', 'var', 'std', 'sem']})
summary_table
# Out:
#              Tumor Volume (mm3)
#                            mean     median        var       std       sem
# Drug Regimen
# Capomulin             40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin              52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol             52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril              55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol              54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo               54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva              52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane              40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn              54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol             53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
#find the number of mice used per drug regimen using the clean dataframe without duplicates
#return only the mouse ID column which will equal the total mice per drug
mice_per_drug = clean_df.groupby('Drug Regimen').count()['Mouse ID']
#sort column by descending to match graph
mice_per_drug = mice_per_drug.sort_values(ascending=False)
mice_per_drug
# Out:
# Drug Regimen
# Capomulin    230
# Ramicane     228
# Ketapril     188
# Naftisol     186
# Zoniferol    182
# Placebo      181
# Stelasyn     181
# Ceftamin     178
# Infubinol    178
# Propriva     148
# Name: Mouse ID, dtype: int64

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using Pandas.
mice_per_drug.plot.bar('Drug Regimen', 'Mouse ID', align='center', )
plt.ylabel('# of Observed Mouse Timepoints')
plt.savefig('bar_drug_timepts.png',bbox_inches='tight')
plt.show()

# %%
clean_df
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0        b128          0           45.000000                 0    Capomulin
# 1        f932          0           45.000000                 0     Ketapril
# 2        g107          0           45.000000                 0     Ketapril
# 3        a457          0           45.000000                 0     Ketapril
# 4        c819          0           45.000000                 0     Ketapril
# ...       ...        ...                 ...               ...          ...
# 1888     r944         45           41.581521                 2    Capomulin
# 1889     u364         45           31.023923                 3    Capomulin
# 1890     p438         45           61.433892                 1     Ceftamin
# 1891     x773         45           58.634971                 4      Placebo
# 1892     b879         45           72.555239                 2     Stelasyn
#
#          Sex  Age_months  Weight (g)
# ...

# %%
#Calculate the number of female and male mice before creating pie chart
mice_by_sex = clean_df.groupby('Sex').count()['Mouse ID']
mice_by_sex = mice_by_sex.sort_values(ascending=False)
# Generate a pie plot showing the distribution of female versus male mice using Pandas
mice_by_sex.plot.pie(y='Sex', autopct='%1.1f%%', ylabel='Sex')
# Out:
# <Axes: ylabel='Sex'>

# %%
## Generate a pie plot showing the distribution of female versus male mice using Pyplot
#generate lists of sex categories and totals
labels = ['Male', 'Female']
sex_population = list(mice_by_sex)
plt.pie(sex_population, labels=labels, autopct='%1.1f%%' )
plt.ylabel('Sex')
plt.savefig('Gender_piechart_pyplot.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin

# Start by getting the last (greatest) timepoint for each mouse
max_pts =clean_df.groupby(['Mouse ID'])['Timepoint'].max()
max_pts = max_pts.reset_index()
new_df = max_pts.merge(clean_df, on=['Mouse ID', 'Timepoint'], how='left')
new_df
# Out:
#     Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0       a203         45           67.973419                 2    Infubinol
# 1       a251         45           65.525743                 1    Infubinol
# 2       a262         45           70.717621                 4      Placebo
# 3       a275         45           62.999356                 3     Ceftamin
# 4       a366         30           63.440686                 1     Stelasyn
# ..       ...        ...                 ...               ...          ...
# 243     z435         10           48.710661                 0     Propriva
# 244     z578         45           30.638696                 0     Ramicane
# 245     z581         45           62.754451                 3    Infubinol
# 246     z795         45           65.741070                 3     Naftisol
# 247     z969         45           73.867845                 4     Naftisol
#
#         Sex  Age_months  Weight (g)
# ...

# %%
# Put treatments into a list for for loop (and later for plot labels)
treatment_drugs = ["Capomulin", "Ramicane", "Infubinol", "Ceftamin"]

# Create empty list to fill with tumor vol data (for plotting)
tumor_vol_data = []

# # Calculate the IQR and quantitatively determine if there are any potential outliers. 
# for drug in treatments:
    
    # Locate the rows which contain mice on each drug and get the tumor volumes
for drug in treatment_drugs:
    # Locate the rows which contain mice on each drug and get the tumor volumes
    tumor = new_df.loc[new_df['Drug Regimen']== drug, 'Tumor Volume (mm3)']
    # add subset
    tumor_vol_data.append(tumor)
    # Determine outliers using upper and lower bounds
    quartiles = tumor.quantile([0.25,0.75])
    lowerq = quartiles[0.25]
    upperq = quartiles[0.75]
    iqr = upperq-lowerq
    lower_bound = lowerq - (1.5*iqr)
    upper_bound = upperq + (1.5*iqr)
    outliers = tumor[(tumor < lower_bound)| (tumor > upper_bound)]
    
    if len(outliers)==0:
        print(f"{drug}'s potential outliers: No outliers found.")
        print('--------------------------------------------------')
    else:
        print(f"{drug}'s potential outliers: {outliers}")
        print('--------------------------------------------------')
# Out:
# Capomulin's potential outliers: No outliers found.
# --------------------------------------------------
# Ramicane's potential outliers: No outliers found.
# --------------------------------------------------
# Infubinol's potential outliers: 31    36.321346
# Name: Tumor Volume (mm3), dtype: float64
# --------------------------------------------------
# Ceftamin's potential outliers: No outliers found.
# --------------------------------------------------

# %%
# Generate a box plot that shows the distrubution of the tumor volume for each treatment group.
fig1, ax = plt.subplots(figsize=(9,7))
ax.set_ylabel('Final Tumor Vol (mm3)')
ax.boxplot(tumor_vol_data)
plt.xticks([1,2,3,4],treatment_drugs)
plt.savefig('Box_whisker_outliers.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a single mouse treated with Capomulin
#find all the mice under capomulin
capomulin_mice = clean_df.loc[clean_df['Drug Regimen']=='Capomulin']
single_mouse = capomulin_mice.loc[capomulin_mice['Mouse ID']=='b128']
single_mouse_vol = single_mouse['Tumor Volume (mm3)']
single_mouse_time = single_mouse['Timepoint']

plt.plot(single_mouse_time, single_mouse_vol)
plt.title('Capomulin Treatment for Mouse b128')
plt.ylabel('Tumor Volume (mm3)')
plt.xlabel('Timepoint (days)')
plt.savefig('line_graph.png', bbox_inches='tight')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
capo_df = capomulin_mice.copy()
capo_df
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0        b128          0           45.000000                 0    Capomulin
# 226      j246          0           45.000000                 0    Capomulin
# 227      r554          0           45.000000                 0    Capomulin
# 228      s185          0           45.000000                 0    Capomulin
# 229      b742          0           45.000000                 0    Capomulin
# ...       ...        ...                 ...               ...          ...
# 1854     s710         45           40.728578                 1    Capomulin
# 1859     j119         45           38.125164                 1    Capomulin
# 1878     i557         45           47.685963                 1    Capomulin
# 1888     r944         45           41.581521                 2    Capomulin
# 1889     u364         45           31.023923                 3    Capomulin
#
#          Sex  Age_months  Weight (g)
# ...

# %%
# Generate a scatter plot of mouse weight vs. the average observed tumor volume for the entire Capomulin regimen
avg_weight = capo_df.groupby('Mouse ID')['Weight (g)'].mean()
avg_vol = capo_df.groupby('Mouse ID')['Tumor Volume (mm3)'].mean()
plt.scatter(avg_weight, avg_vol)
plt.ylabel('Average Tumor Volume (mm3)')
plt.xlabel('Weight (g)')
plt.savefig('scatter_plot.png', bbox_inches='tight')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and a linear regression model 
# for mouse weight and average observed tumor volume for the entire Capomulin regimen
correlation = st.pearsonr(avg_weight, avg_vol)
co_stat = round(correlation[0], 2)
print(f'The correlation between mouse weight and the average tumor volume is {co_stat}')
#linear regression
x_value = avg_weight
y_value = avg_vol
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_value, y_value)
regress_value=x_value*slope + intercept
line_eq = 'y = ' + str(round(slope,2)) + 'x +' + str(round(intercept,2))
plt.scatter(x_value, y_value)
plt.xlabel("Weight (g)")
plt.ylabel("Tumor Volume (mm3)")
plt.plot(x_value,regress_value, 'r-')
plt.savefig('regression.png', bbox_inches='tight')
plt.show()
# Out:
# The correlation between mouse weight and the average tumor volume is 0.84
